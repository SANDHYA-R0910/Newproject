# %%
import pandas as pd

# %%
raw_data=pd.read_excel("D01JAN2022_.xlsx",header=None)

# %%
def df(filename, row_i, row_j, col_i, col_j):
    raw_data = pd.read_excel(filename, usecols = str(col_i)+":"+str(col_j))
    return raw_data[row_i:row_j]

data = df("D01JAN2022_.xlsx", 17, 39, "A", "L")
data
# Out:
#    Unnamed: 0             Unnamed: 1  Unnamed: 2  Unnamed: 3 Unnamed: 4  \
# 17        NaN               STATIONS         NaN         NaN        NO.
# 18          1               R.T.P.S.         NaN         NaN          8
# 19        NaN               B.T.P.S.         NaN         NaN          3
# 20          3               Y.T.P.S.         NaN         NaN          2
# 21          4             SHARAVATHY         NaN         NaN         10
# 22        450               N. P. H.         NaN         NaN          6
# 23          6                 VARAHI         NaN         NaN          4
# 24          7              GERUSOPPA         NaN         NaN          4
# 25          8                ALMATTI         NaN         NaN          6
# 26        NaN                  KADRA         NaN         NaN          3
# 27         10              KODASALLY         NaN         NaN          3
# 28        NaN                   SUPA         NaN         NaN          2
# ...

# %%
data.head(10)
# Out:
#    Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 17        NaN    STATIONS         NaN         NaN        NO.       (MW)
# 18          1    R.T.P.S.         NaN         NaN          8       1720
# 19        NaN    B.T.P.S.         NaN         NaN          3       1700
# 20          3    Y.T.P.S.         NaN         NaN          2       1600
# 21          4  SHARAVATHY         NaN         NaN         10       1035
# 22        450    N. P. H.         NaN         NaN          6        900
# 23          6      VARAHI         NaN         NaN          4        460
# 24          7   GERUSOPPA         NaN         NaN          4        240
# 25          8     ALMATTI         NaN         NaN          6        290
# 26        NaN       KADRA         NaN         NaN          3        150
#
#    Unnamed: 6   Unnamed: 7   Unnamed: 8 Unnamed: 9  Unnamed: 10 Unnamed: 11
# 17      Units  at MAX load  at MIN load       (MU)          NaN        (MW)
# ...

# %%
raw_data = pd.read_excel("D01JAN2022_.xlsx", 
                   usecols='B:D')
raw_data
# Out:
#                                            Unnamed: 1  Unnamed: 2  Unnamed: 3
# 0                                                 NaN         NaN         NaN
# 1                                                 NaN         NaN         NaN
# 2                                                 NaN         NaN         NaN
# 3                                                 NaN         NaN         NaN
# 4                                                 NaN         NaN         NaN
# ..                                                ...         ...         ...
# 69                                                NaN         NaN         NaN
# 70                          Energy Consumed till date         NaN  199.465844
# 71                                                NaN         NaN         NaN
# 72                                                NaN         NaN         NaN
# 73  *1) Installed Capacity of Railways and Jindal ...         NaN         NaN
#
# [74 rows x 3 columns]

# %%
raw_data = pd.read_excel('D01JAN2022_.xlsx', 
                   skiprows=lambda x: x in [1,3])
print(raw_data)
# Out:
#                    Unnamed: 0  \
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# ..                        ...
# 67                        NaN
# 68  Energy consumed till date
# 69                        NaN
# 70                        NaN
# 71                        NaN
#
#                                            Unnamed: 1  Unnamed: 2  Unnamed: 3  \
# 0                                                 NaN         NaN         NaN
# 1                                                 NaN         NaN         NaN
# 2                                                 NaN         NaN         NaN
# 3                                                 NaN         NaN         NaN
# 4                                                 NaN         NaN         NaN
# ..                                                ...         ...         ...
# ...

# %%
header_idx = raw_data[
    raw_data[1].eq('STATIONS')
]
header_idx
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
footer_idx = raw_data[
    raw_data[1].eq('Count')
].index.values[0] - 1
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
import pandas as pd

# %%
pd.read_excel("New Microsoft Office Excel Worksheet.xlsx")
# Out:
#    RESERVOIR  DETAILS  AT  0800 HRS ON 2 ND JANUARY-2022  \
# 0    RESERVOIR,FULL RESERVOIR LEVEL ,CAPACITY IN MCFT
# 1                                                 NaN
# 2                                               LEVEL
# 3                                   LIVE CAPTY.(Mcft)
# 4                                      EQ.ENERGY (MU)
# 5                                           % STORAGE
# 6                                INFLOW ( in Cusecs )
# 7                                    INFLOW ( in MU )
# 8                                  DISCHARGE (Cusecs)
# 9                   Inflow during the month (in Mcft)
# 10                    Inflow during the month (in MU)
# 11               I.F.PROGRESS.FROM 1.6.2021 (Mcft)
# 12                                                NaN
# 13                                         Tattihalla
# 14                                       Bommanahalli
#
#                                            Unnamed: 1  \
# ...

# %%
f = open("D01JAN2022_.xlsx", "r")
for row in f:
    singleRow = row.split(",") #replace the "," with the delimiter you chose to seperate your columns
    print (singleRow
